# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("c:\\Users\\dipan\\Downloads\\seasonal_agriculture_performance_dataset.csv")
df.head(5)
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
df.shape
# Out:
# (4000, 28)

# %%
df.columns
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')

# %%
datatypes = df.dtypes
datatypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
#statistical summary of the dataset
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  3952.000000         4000.00000   4000.000000
# mean             7.888265   601.152657           26.81890     63.210500
# std              4.223764   288.925025            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   370.200000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   834.950000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        3960.000000     4000.000000
# mean             7.323050     6.701010          26.508232      120.250825
# std              1.121186     0.641461           6.712484       31.216452
# ...

# %%
#numerical summary of the dataset
df.describe(include = "all")
# Out:
#         Farm_ID           State  District  Crop  Season  Farm_Area_Hectares  \
# count      4000            4000      4000  4000    4000         4000.000000
# unique     4000               8        10     8       3                 NaN
# top     SF10001  Andhra Pradesh  Ludhiana  Rice  Kharif                 NaN
# freq          1             529       427   690    1779                 NaN
# mean        NaN             NaN       NaN   NaN     NaN            7.888265
# std         NaN             NaN       NaN   NaN     NaN            4.223764
# min         NaN             NaN       NaN   NaN     NaN            0.500000
# 25%         NaN             NaN       NaN   NaN     NaN            4.260000
# 50%         NaN             NaN       NaN   NaN     NaN            7.895000
# 75%         NaN             NaN       NaN   NaN     NaN           11.650000
# max         NaN             NaN       NaN   NaN     NaN           15.000000
#
# ...

# %%
#identify categorical and numerical columns
categorical_columns = df.select_dtypes(include = "object").columns
numerical_columns = df.select_dtypes(include = np.number).columns

print(categorical_columns)
print(categorical_columns.tolist())
print(numerical_columns)
print(numerical_columns.tolist())
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Irrigation_Method'], dtype='object')
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Irrigation_Method']
# Index(['Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C',
#        'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct',
#        'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')
# ...

# %%
#Check Available Seasons
df["Season"].value_counts()
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
df["Season"].unique()
# Out:
# array(['Kharif', 'Rabi', 'Zaid'], dtype=object)

# %%
#Initial Missing Value Check
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
#Data Cleaning and Preparation
missing_values = df.isnull().sum()

missing_values[missing_values > 0]
# Out:
# Rainfall_mm          48
# Soil_Moisture_pct    40
# Yield_Tonnes_Ha      32
# dtype: int64

# %%
#Before replacing missing values, let's check the distribution of the columns.
df[["Rainfall_mm", "Soil_Moisture_pct", "Yield_Tonnes_Ha"]].describe()
# Out:
#        Rainfall_mm  Soil_Moisture_pct  Yield_Tonnes_Ha
# count  3952.000000        3960.000000      3968.000000
# mean    601.152657          26.508232         5.270595
# std     288.925025           6.712484        13.361398
# min      80.000000           8.000000         0.300000
# 25%     370.200000          21.700000         1.050000
# 50%     582.000000          26.400000         1.740000
# 75%     834.950000          31.300000         2.840000
# max    1395.200000          47.000000       101.440000

# %%
#these are numerical columns, we can use the median to fill missing values
df["Rainfall_mm"] = df["Rainfall_mm"].fillna(
    df["Rainfall_mm"].median()
)

df["Soil_Moisture_pct"] = df["Soil_Moisture_pct"].fillna(
    df["Soil_Moisture_pct"].median()
)

df["Yield_Tonnes_Ha"] = df["Yield_Tonnes_Ha"].fillna(
    df["Yield_Tonnes_Ha"].median()
)

# %%
#now cheak ios if there are any missing values left
df.isnull().sum()
# there is no missing value is left now
# Out:
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# Water_Used_m3                    0
# Water_Efficiency_t_per_1000m3    0
# ...

# %%
#Check for Duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#cheak data type again 
df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
#make columns name consistentdf.
columns = (
    df.columns
    .str.strip()
    .str.replace(" ", "_")
)

# %%
df.columns.tolist()
# now in placwe of spaces we have underscore in the column names
# Out:
# ['Farm_ID',
#  'State',
#  'District',
#  'Crop',
#  'Season',
#  'Farm_Area_Hectares',
#  'Rainfall_mm',
#  'Avg_Temperature_C',
#  'Humidity_pct',
#  'Sunlight_Hours_Day',
#  'Soil_pH',
#  'Soil_Moisture_pct',
#  'Nitrogen_kg_ha',
#  'Phosphorus_kg_ha',
#  'Potassium_kg_ha',
#  'Irrigation_Method',
#  'Fertilizer_kg_ha',
#  'Pesticide_Litre_ha',
#  'Seed_Quality_Score',
#  'Yield_Tonnes_Ha',
#  'Production_Tonnes',
#  'Market_Price_INR_Tonne',
#  'Total_Cost_INR',
#  'Revenue_INR',
#  'Profit_INR',
#  'Water_Used_m3',
#  'Water_Efficiency_t_per_1000m3',
#  'Disease_Pest_Risk_pct']

# %%
#Check Categorical Values
categorical_columns = df.select_dtypes(include="object").columns

for column in categorical_columns:
    print(f"\n{column}")
    print(df[column].unique())
    
#here we can see that the column "Season" has inconsistent values. We can fix this by replacing the inconsistent values with the correct ones.
# Out:
# Farm_ID
# ['SF10001' 'SF10002' 'SF10003' ... 'SF13998' 'SF13999' 'SF14000']
#
# State
# ['Andhra Pradesh' 'Maharashtra' 'Telangana' 'Karnataka' 'Gujarat'
#  'Tamil Nadu' 'Punjab' 'Madhya Pradesh']
#
# District
# ['Rajkot' 'Nalgonda' 'Warangal' 'Indore' 'Ludhiana' 'Raichur' 'Guntur'
#  'Krishna' 'Nashik' 'Erode']
#
# Crop
# ['Wheat' 'Maize' 'Pulses' 'Rice' 'Cotton' 'Chilli' 'Groundnut' 'Sugarcane']
#
# Season
# ['Kharif' 'Rabi' 'Zaid']
#
# Irrigation_Method
# ['Drip' 'Flood' 'Rainfed' 'Sprinkler']

# %%
#Standardize Categorical Data
for column in categorical_columns:
    df[column] = df[column].str.strip()

# %%
df["Season"] = df["Season"].str.title()

# %%
df["Season"].value_counts()
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
numerical_columns = df.select_dtypes(include=np.number).columns

for column in numerical_columns:
    negative_values = (df[column] < 0).sum()
    
    if negative_values > 0:
        print(f"{column}: {negative_values} negative values")
# Out:
# Profit_INR: 1966 negative values

# %%
#Check Outliers
outlier_columns = [
    "Rainfall_mm",
    "Temperature_C",
    "Soil_Moisture_pct",
    "Yield_Tonnes_Ha",
    "Production_Tonnes",
    "Revenue_INR",
    "Profit_INR"
]

# Keep only columns that actually exist in the dataset
existing_columns = [
    column for column in outlier_columns
    if column in df.columns
]

print("Columns available for outlier analysis:")
print(existing_columns)
# we can use boxplots to visualize the outliers in the numerical columns
# Out:
# Columns available for outlier analysis:
# ['Rainfall_mm', 'Soil_Moisture_pct', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Revenue_INR', 'Profit_INR']

# %%
plt.figure(figsize=(15, 8))

for i, column in enumerate(existing_columns, 1):
    plt.subplot(2, 4, i)
    sns.boxplot(y=df[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %%
#Data Quality Checkagain 
print("Dataset Shape:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())

print("\nData Types:")
print(df.dtypes)
# Out:
# Dataset Shape: (4000, 28)
#
# Missing Values:
# 0
#
# Duplicate Rows:
# 0
#
# Data Types:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# ...

# %%
#save
df.to_csv(
    "seasonal_agriculture_cleaned.csv",
    index=False
)

# %%
#till now we do these steps:
#Missing values handled
#Duplicate rows checked
 #Column names cleaned
 #Categorical values standardized
 #Data types verified
#Invalid values checked
 #Outliers explored
 #Cleaned dataset saved

# %%
#now we do Exploratory Data Analysis

# %%
print(df.columns.tolist())
# Out:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']

# %%
season_counts = df["Season"].value_counts()

print(season_counts)
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
# here we can see that the dataset has records for all four seasons: Kharif, Rabi, Summer, and Winter. We can visualize the distribution of records across seasons using a bar plot.
plt.figure(figsize=(8, 5))

sns.countplot(data=df, x="Season")

plt.title("Distribution of Agricultural Records Across Seasons")
plt.xlabel("Season")
plt.ylabel("Number of Records")

plt.show()

# %%
# we cheak the average values of numerical columns for each season to understand how different seasons affect agricultural performance. This can help us identufy trends and patterns in the data.
season_summary = df.groupby("Season").mean(numeric_only=True)

season_summary
# Out:
#         Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Season
# Kharif            7.944924   849.199663          28.454019     71.812591
# Rabi              7.752207   437.615366          23.489183     57.893178
# Zaid              8.091246   304.654714          31.042088     52.012121
#
#         Sunlight_Hours_Day   Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# Season
# Kharif            6.793367  6.727993          31.149859      120.020124
# Rabi              7.589797  6.673749          24.069392      120.402827
# Zaid              8.178788  6.694865          19.279630      120.525421
#
#         Phosphorus_kg_ha  Potassium_kg_ha  ...  Seed_Quality_Score  \
# Season                                     ...
# Kharif         58.096515       105.303485  ...            0.821613
# Rabi           57.311002       103.926060  ...            0.832170
# Zaid           58.129125       105.416835  ...            0.823165
#
# ...

# %%
#bar plot  using matplotlib to visualize the average yield for each season.
plt.figure(figsize=(8, 5))

plt.bar(season_summary.index, season_summary["Yield_Tonnes_Ha"], color='skyblue')
plt.title("Average Agricultural Yield by Season")
plt.xlabel("Season")
plt.ylabel("Average Yield (Tonnes per Hectare)")

plt.show()

# %%
#Total Production by Season

total_production = (
    df.groupby("Season")["Production_Tonnes"]
    .sum()
    .sort_values(ascending=False)
)

print(total_production)
# Out:
# Season
# Kharif    82387.61
# Rabi      67498.88
# Zaid      23098.35
# Name: Production_Tonnes, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    x=total_production.index,
    y=total_production.values
)

plt.title("Total Agricultural Production by Season")
plt.xlabel("Season")
plt.ylabel("Total Production")

plt.show()

# %%
#average Revenue by Season
average_revenue = (
    df.groupby("Season")["Revenue_INR"]
    .mean()
    .sort_values(ascending=False)
)
print(average_revenue)
# Out:
# Season
# Kharif    710719.055649
# Rabi      601526.048556
# Zaid      519171.904040
# Name: Revenue_INR, dtype: float64

# %%
#barplot using matlotlib to visualize the average revenue for each season.
plt.figure(figsize=(8, 5))
plt.bar(average_revenue.index, average_revenue.values, color='lightgreen')
# Out:
# <BarContainer object of 3 artists>

# %%
#avg profit per season
average_profit = (
    df.groupby("Season")["Profit_INR"]
    .mean()
    .sort_values(ascending=False)
)
print(average_profit)
# Out:
# Season
# Kharif    178914.647555
# Rabi       87689.470191
# Zaid      -24804.824916
# Name: Profit_INR, dtype: float64

# %%
#use seaboernfro barplot to visualize the average profit for each season.
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y="Profit_INR",
    estimator="mean"
)

plt.title("Average Profit by Season")
plt.xlabel("Season")
plt.ylabel("Average Profit (INR)")

plt.show()

# %%
#Complete Seasonal Performance Table
performance_columns = [
    "Yield_Tonnes_Ha",
    "Production_Tonnes",
    "Revenue_INR",
    "Profit_INR"
]


performance_columns = [
    col for col in performance_columns
    if col in df.columns
]

season_performance = (
    df.groupby("Season")[performance_columns]
    .mean()
    .round(2)
)

season_performance
# Out:
#         Yield_Tonnes_Ha  Production_Tonnes  Revenue_INR  Profit_INR
# Season
# Kharif             5.63              46.31    710719.06   178914.65
# Rabi               5.04              41.49    601526.05    87689.47
# Zaid               4.64              38.89    519171.90   -24804.82

# %%
#now we Compare Seasonal Performance Using a Heatmap
plt.figure(figsize=(12, 6))

sns.heatmap(
    season_performance,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu"
)

plt.title("Seasonal Agricultural Performance Comparison")

plt.show()

# %%
# now Identify the Best Season for Each Metric
best_seasons = {}

for column in performance_columns:
    best_season = season_performance[column].idxmax()
    best_value = season_performance[column].max()

    best_seasons[column] = {
        "Best Season": best_season,
        "Value": best_value
    }

best_seasons
# Out:
# {'Yield_Tonnes_Ha': {'Best Season': 'Kharif', 'Value': 5.63},
#  'Production_Tonnes': {'Best Season': 'Kharif', 'Value': 46.31},
#  'Revenue_INR': {'Best Season': 'Kharif', 'Value': 710719.06},
#  'Profit_INR': {'Best Season': 'Kharif', 'Value': 178914.65}}

# %%
best_seasons_df = pd.DataFrame(best_seasons).T

best_seasons_df
# Out:
#                   Best Season      Value
# Yield_Tonnes_Ha        Kharif       5.63
# Production_Tonnes      Kharif      46.31
# Revenue_INR            Kharif  710719.06
# Profit_INR             Kharif  178914.65

# %%
# Questions and Answers

# 1. Which season has the highest average yield?
# Answer: Kharif Season

# Season: Kharif | Average Yield: 5.63 Tonnes/Ha
# Season: Rabi   | Average Yield: 5.04 Tonnes/Ha
# Season: Zaid   | Average Yield: 4.64 Tonnes/Ha

# Conclusion: Kharif has the highest average agricultural yield of
# 5.63 tonnes per hectare.

# ------------------------------------------------------------

# 2. Which season has the highest total production?
# Answer: Kharif Season

# Kharif: 82,387.61 Tonnes
# Rabi:   67,498.88 Tonnes
# Zaid:   23,098.35 Tonnes

# Conclusion: Kharif has the highest total production.

# ------------------------------------------------------------

# 3. Which season generates the highest average revenue?
# Answer: Kharif Season

# Kharif: Rs. 710,719.06
# Rabi:   Rs. 601,526.05
# Zaid:   Rs. 519,171.90

# Conclusion: Kharif generates the highest average revenue.

# ------------------------------------------------------------

# 4. Which season generates the highest average profit?
# Answer: Kharif Season

# Kharif: Rs. 178,914.65
# Rabi:   Rs. 87,689.47
# Zaid:   -Rs. 24,804.82

# Conclusion: Kharif generates the highest average profit.

# Important Observation:
# Zaid has a negative average profit, meaning agricultural activities
# during this season resulted in an average loss.

# ------------------------------------------------------------

# 5. Does the same season perform best across every metric?
# Answer: Yes

# Highest Average Yield: Kharif
# Highest Total Production: Kharif
# Highest Average Revenue: Kharif
# Highest Average Profit: Kharif

# ------------------------------------------------------------

# Overall Conclusion:
# Kharif is the best-performing season across all four key agricultural
# performance metrics in this dataset.

# Kharif shows better productivity and economic outcomes compared
# with Rabi and Zaid.

# %%
# after answerting some questions we can conclude that Kharif is the best-performing season across all four key agricultural performance metrics in this dataset. Kharif shows better productivity and economic outcomes compared with Rabi and Zaid.

#now we movwe forword  to do 
#Environmental Conditions and Their Relationship with Agricultural Performance

#We will analyze:

#Rainfall across seasons
#Average temperature across seasons
#Humidity across seasons
#Soil moisture across seasons
#Relationship between environmental factors and crop yield

# %%
###Environmental Conditions Analysis vs agriculture performance

# %%
# in this section we will analyze the environmental conditions across different seasons and their relationship with agricultural performance. We will focus on key environmental factors such as rainfall, average temperature, humidity, sunlight hours, and soil moisture.
environmental_columns = [
    "Rainfall_mm",
    "Avg_Temperature_C",
    "Humidity_pct",
    "Sunlight_Hours_Day",
    "Soil_Moisture_pct"
]

season_environment = (
    df.groupby("Season")[environmental_columns]
    .mean()
    .round(2)
)

season_environment
# it tells us Rainfall between seasons
#Temperature between seasons
#Humidity between seasons
#Sunlight exposure between seasons
#Soil moisture between seasons
# Out:
#         Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# Season
# Kharif       849.20              28.45         71.81                6.79
# Rabi         437.62              23.49         57.89                7.59
# Zaid         304.65              31.04         52.01                8.18
#
#         Soil_Moisture_pct
# Season
# Kharif              31.15
# Rabi                24.07
# Zaid                19.28

# %%
#average riannfall by season
average_rainfall = (
    df.groupby("Season")["Rainfall_mm"]
    .mean()
    .sort_values(ascending=False)
)

print(average_rainfall)
# Out:
# Season
# Kharif    849.199663
# Rabi      437.615366
# Zaid      304.654714
# Name: Rainfall_mm, dtype: float64

# %%
#barplot 
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y="Rainfall_mm",
    estimator="mean"
)

plt.title("Average Rainfall by Season")
plt.xlabel("Season")
plt.ylabel("Average Rainfall (mm)")

plt.show()

# %%
#average temperature by season
average_temperature = (
    df.groupby("Season")["Avg_Temperature_C"]
    .mean()
    .sort_values(ascending=False)
)

print(average_temperature)
# Out:
# Season
# Zaid      31.042088
# Kharif    28.454019
# Rabi      23.489183
# Name: Avg_Temperature_C, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y="Avg_Temperature_C",
    estimator="mean"
)

plt.title("Average Temperature by Season")
plt.xlabel("Season")
plt.ylabel("Average Temperature (°C)")

plt.show()

# %%
#average humidity by season
average_humidity = (
    df.groupby("Season")["Humidity_pct"]
    .mean()
    .sort_values(ascending=False)
)

print(average_humidity)
# Out:
# Season
# Kharif    71.812591
# Rabi      57.893178
# Zaid      52.012121
# Name: Humidity_pct, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y="Humidity_pct",
    estimator="mean"
)

plt.title("Average Humidity by Season")
plt.xlabel("Season")
plt.ylabel("Average Humidity (%)")

plt.show()

# %%
#average soil moisture by season
average_soil_moisture = (
    df.groupby("Season")["Soil_Moisture_pct"]
    .mean()
    .sort_values(ascending=False)
)

print(average_soil_moisture)
# Out:
# Season
# Kharif    31.149859
# Rabi      24.069392
# Zaid      19.279630
# Name: Soil_Moisture_pct, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y="Soil_Moisture_pct",
    estimator="mean"
)

plt.title("Average Soil Moisture by Season")
plt.xlabel("Season")
plt.ylabel("Average Soil Moisture (%)")

plt.show()

# %%
#avg sunlight hours by season
average_sunlight = (
    df.groupby("Season")["Sunlight_Hours_Day"]
    .mean()
    .sort_values(ascending=False)
)

print(average_sunlight)
# Out:
# Season
# Zaid      8.178788
# Rabi      7.589797
# Kharif    6.793367
# Name: Sunlight_Hours_Day, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y="Sunlight_Hours_Day",
    estimator="mean"
)

plt.title("Average Sunlight Hours by Season")
plt.xlabel("Season")
plt.ylabel("Average Sunlight Hours per Day")

plt.show()

# %%
#now heat map of Environmental Conditions Comparison 
plt.figure(figsize=(12, 6))

sns.heatmap(
    season_environment,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu"
)

plt.title("Environmental Conditions Across Seasons")

plt.xlabel("Environmental Factors")
plt.ylabel("Season")

plt.show()

# %%
#Relationship Between Environmental Factors and Yield
environment_yield_columns = [
    "Rainfall_mm",
    "Avg_Temperature_C",
    "Humidity_pct",
    "Sunlight_Hours_Day",
    "Soil_Moisture_pct",
    "Yield_Tonnes_Ha"
]

correlation_matrix = (
    df[environment_yield_columns]
    .corr()
    .round(2)
)

correlation_matrix
# Out:
#                     Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Rainfall_mm                1.00               0.20          0.52
# Avg_Temperature_C          0.20               1.00          0.14
# Humidity_pct               0.52               0.14          1.00
# Sunlight_Hours_Day        -0.36              -0.03         -0.30
# Soil_Moisture_pct          0.51               0.08          0.45
# Yield_Tonnes_Ha            0.03               0.01          0.01
#
#                     Sunlight_Hours_Day  Soil_Moisture_pct  Yield_Tonnes_Ha
# Rainfall_mm                      -0.36               0.51             0.03
# Avg_Temperature_C                -0.03               0.08             0.01
# Humidity_pct                     -0.30               0.45             0.01
# Sunlight_Hours_Day                1.00              -0.30            -0.02
# Soil_Moisture_pct                -0.30               1.00             0.01
# ...

# %%
#heatmap to visualize the correlation between environmental factors and agricultural yield.
plt.figure(figsize=(10, 7))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Between Environmental Factors and Agricultural Yield")

plt.show()

# %%
#Relationship Between Rainfall and Agricultural Yield
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Rainfall_mm",
    y="Yield_Tonnes_Ha",
    hue="Season",
    alpha=0.6
)

plt.title("Relationship Between Rainfall and Agricultural Yield")

plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (Tonnes per Hectare)")

plt.show()
# we use scatterplot

# %%
#Relationship Between Temperature and Agricultural Yield
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Avg_Temperature_C",
    y="Yield_Tonnes_Ha",
    hue="Season",
    alpha=0.6
)

plt.title("Relationship Between Temperature and Agricultural Yield")

plt.xlabel("Average Temperature (°C)")
plt.ylabel("Yield (Tonnes per Hectare)")

plt.show()

# %%
#Relationship Between Humidity and Agricultural Yield

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Soil_Moisture_pct",
    y="Yield_Tonnes_Ha",
    hue="Season",
    alpha=0.6
)

plt.title("Relationship Between Soil Moisture and Agricultural Yield")

plt.xlabel("Soil Moisture (%)")
plt.ylabel("Yield (Tonnes per Hectare)")

plt.show()

# %%
#Now we will analyze how agricultural resources are used across different seasons

print(df.columns.tolist())
# Out:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']

# %%
resource_keywords = [
    "water",
    "fertilizer",
    "pesticide",
    "irrigation",
    "efficiency"
]

resource_columns = [
    col for col in df.columns
    if any(keyword in col.lower() for keyword in resource_keywords)
]

print(resource_columns)
# Out:
# ['Irrigation_Method', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3']

# %%
numerical_resource_columns = [
    col for col in resource_columns
    if pd.api.types.is_numeric_dtype(df[col])
]

print(numerical_resource_columns)
# Out:
# ['Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3']

# %%
# avg resource usage by season
season_resource_summary = (
    df.groupby("Season")[numerical_resource_columns]
    .mean()
    .round(2)
)

season_resource_summary
# Out:
#         Fertilizer_kg_ha  Pesticide_Litre_ha  Water_Used_m3  \
# Season
# Kharif            187.08                5.08        6102.20
# Rabi              185.41                5.02        5846.99
# Zaid              184.64                5.17        6419.89
#
#         Water_Efficiency_t_per_1000m3
# Season
# Kharif                           5.89
# Rabi                             5.19
# Zaid                             4.41

# %%
season_resource_summary.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Average Resource Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Value")

plt.xticks(rotation=0)

plt.legend(title="Resources")

plt.tight_layout()
plt.show()

# %%
# Plot the average resource usage by season
season_resource_summary.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Average Resource Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Value")

plt.xticks(rotation=0)

plt.legend(title="Resources")

plt.tight_layout()
plt.show()

# %%
#Water Usage by Season
water_columns = [
    col for col in df.columns
    if "water" in col.lower()
    and pd.api.types.is_numeric_dtype(df[col])
]

print(water_columns)
# Out:
# ['Water_Used_m3', 'Water_Efficiency_t_per_1000m3']

# %%
water_column = water_columns[0]

water_by_season = (
    df.groupby("Season")[water_column]
    .mean()
    .sort_values(ascending=False)
)

print(water_by_season)
# Out:
# Season
# Zaid      6419.893939
# Kharif    6102.201237
# Rabi      5846.987093
# Name: Water_Used_m3, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y=water_column,
    estimator="mean"
)

plt.title("Average Water Usage by Season")
plt.xlabel("Season")
plt.ylabel("Average Water Usage")

plt.show()

# %%
#Fertilizer Usage by Season
fertilizer_columns = [
    col for col in df.columns
    if "fertilizer" in col.lower()
    and pd.api.types.is_numeric_dtype(df[col])
]

print(fertilizer_columns)
# Out:
# ['Fertilizer_kg_ha']

# %%
fertilizer_column = fertilizer_columns[0]

fertilizer_by_season = (
    df.groupby("Season")[fertilizer_column]
    .mean()
    .sort_values(ascending=False)
)

print(fertilizer_by_season)
# Out:
# Season
# Kharif    187.077965
# Rabi      185.407068
# Zaid      184.638047
# Name: Fertilizer_kg_ha, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y=fertilizer_column,
    estimator="mean"
)

plt.title("Average Fertilizer Usage by Season")
plt.xlabel("Season")
plt.ylabel("Average Fertilizer Usage")

plt.show()

# %%
#Pesticides Usage by Season
pesticide_columns = [
    col for col in df.columns
    if "pesticide" in col.lower()
    and pd.api.types.is_numeric_dtype(df[col])
]

print(pesticide_columns)
# Out:
# ['Pesticide_Litre_ha']

# %%
pesticide_column = pesticide_columns[0]

pesticide_by_season = (
    df.groupby("Season")[pesticide_column]
    .mean()
    .sort_values(ascending=False)
)

print(pesticide_by_season)
# Out:
# Season
# Zaid      5.171212
# Kharif    5.079747
# Rabi      5.024690
# Name: Pesticide_Litre_ha, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y=pesticide_column,
    estimator="mean"
)

plt.title("Average Pesticide Usage by Season")
plt.xlabel("Season")
plt.ylabel("Average Pesticide Usage")

plt.show()

# %%
#integration method distribution by seasonm

# %%
irrigation_columns = [
    col for col in df.columns
    if "irrigation" in col.lower()
    and df[col].dtype == "object"
]

print(irrigation_columns)
# Out:
# ['Irrigation_Method']

# %%
irrigation_column = irrigation_columns[0]

irrigation_by_season = pd.crosstab(
    df["Season"],
    df[irrigation_column]
)

irrigation_by_season
# Out:
# Irrigation_Method  Drip  Flood  Rainfed  Sprinkler
# Season
# Kharif              405    590      463        321
# Rabi                370    526      438        293
# Zaid                140    194      140        120

# %%
irrigation_by_season.plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Irrigation Methods Across Seasons")
plt.xlabel("Season")
plt.ylabel("Number of Agricultural Records")

plt.xticks(rotation=0)

plt.legend(title="Irrigation Method")

plt.tight_layout()
plt.show()

# %%
# Most Common Irrigation Methods by Season
most_common_irrigation = (
    df.groupby("Season")[irrigation_column]
    .agg(lambda x: x.value_counts().idxmax())
)

print(most_common_irrigation)
# Out:
# Season
# Kharif    Flood
# Rabi      Flood
# Zaid      Flood
# Name: Irrigation_Method, dtype: object

# %%
#Water Efficiency by Season

# %%
efficiency_columns = [
    col for col in df.columns
    if "efficiency" in col.lower()
    and pd.api.types.is_numeric_dtype(df[col])
]

print(efficiency_columns)
# Out:
# ['Water_Efficiency_t_per_1000m3']

# %%
efficiency_column = efficiency_columns[0]

efficiency_by_season = (
    df.groupby("Season")[efficiency_column]
    .mean()
    .sort_values(ascending=False)
)

print(efficiency_by_season)
# Out:
# Season
# Kharif    5.891834
# Rabi      5.186122
# Zaid      4.413239
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
efficiency_column = efficiency_columns[0]

efficiency_by_season = (
    df.groupby("Season")[efficiency_column]
    .mean()
    .sort_values(ascending=False)
)

print(efficiency_by_season)
# Out:
# Season
# Kharif    5.891834
# Rabi      5.186122
# Zaid      4.413239
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y=efficiency_column,
    estimator="mean"
)

plt.title("Average Water Efficiency by Season")
plt.xlabel("Season")
plt.ylabel("Average Water Efficiency")

plt.show()

# %%
#Economic Performance Analysis
#First, check the available economic-related columns:
economic_keywords = [
    "revenue",
    "cost",
    "profit",
    "price"
]

economic_columns = [
    col for col in df.columns
    if any(keyword in col.lower() for keyword in economic_keywords)
]

print(economic_columns)
# Out:
# ['Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR']

# %%
numerical_economic_columns = [
    col for col in economic_columns
    if pd.api.types.is_numeric_dtype(df[col])
]

print(numerical_economic_columns)
# Out:
# ['Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR']

# %%
#
# seasonal summary
season_economic_summary = (
    df.groupby("Season")[numerical_economic_columns]
    .mean()
    .round(2)
)

season_economic_summary
# Out:
#         Market_Price_INR_Tonne  Total_Cost_INR  Revenue_INR  Profit_INR
# Season
# Kharif                44850.91       531804.41    710719.06   178914.65
# Rabi                  44747.97       513836.58    601526.05    87689.47
# Zaid                  44212.03       543976.73    519171.90   -24804.82

# %%
#avg ravanue buy season
revenue_columns = [
    col for col in df.columns
    if "revenue" in col.lower()
    and pd.api.types.is_numeric_dtype(df[col])
]

print(revenue_columns)
# Out:
# ['Revenue_INR']

# %%
revenue_column = revenue_columns[0]

revenue_by_season = (
    df.groupby("Season")[revenue_column]
    .mean()
    .sort_values(ascending=False)
)

print(revenue_by_season)
# Out:
# Season
# Kharif    710719.055649
# Rabi      601526.048556
# Zaid      519171.904040
# Name: Revenue_INR, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y=revenue_column,
    estimator="mean"
)

plt.title("Average Revenue by Season")
plt.xlabel("Season")
plt.ylabel("Average Revenue")

plt.show()

# %%
#avg cost
cost_columns = [
    col for col in df.columns
    if "cost" in col.lower()
    and pd.api.types.is_numeric_dtype(df[col])
]

print(cost_columns)
# Out:
# ['Total_Cost_INR']

# %%
cost_column = cost_columns[0]

cost_by_season = (
    df.groupby("Season")[cost_column]
    .mean()
    .sort_values(ascending=False)
)

print(cost_by_season)

plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y=cost_column,
    estimator="mean"
)

plt.title("Average Agricultural Cost by Season")
plt.xlabel("Season")
plt.ylabel("Average Cost")

plt.show()
# Out:
# Season
# Zaid      543976.728956
# Kharif    531804.408094
# Rabi      513836.578365
# Name: Total_Cost_INR, dtype: float64

# %%
#avg  profit 
profit_columns = [
    col for col in df.columns
    if "profit" in col.lower()
    and pd.api.types.is_numeric_dtype(df[col])
]

print(profit_columns)
# Out:
# ['Profit_INR']

# %%
profit_column = profit_columns[0]

profit_by_season = (
    df.groupby("Season")[profit_column]
    .mean()
    .sort_values(ascending=False)
)

print(profit_by_season)
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y=profit_column,
    estimator="mean"
)

plt.title("Average Profit by Season")
plt.xlabel("Season")
plt.ylabel("Average Profit")

plt.show()
# Out:
# Season
# Kharif    178914.647555
# Rabi       87689.470191
# Zaid      -24804.824916
# Name: Profit_INR, dtype: float64

# %%
# now we calculate the profit margin 
df["Profit_Margin_pct"] = (
    df[profit_column] / df[revenue_column]
) * 100

# %%
#avg pprofiit
profit_margin_by_season = (
    df.groupby("Season")["Profit_Margin_pct"]
    .mean()
    .sort_values(ascending=False)
    .round(2)
)

print(profit_margin_by_season)
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="Season",
    y="Profit_Margin_pct",
    estimator="mean"
)

plt.title("Average Profit Margin by Season")
plt.xlabel("Season")
plt.ylabel("Profit Margin (%)")

plt.show()
# Out:
# Season
# Kharif   -38.64
# Rabi     -44.27
# Zaid     -69.35
# Name: Profit_Margin_pct, dtype: float64

# %%
# no we compare the main economic indicators together:
economic_comparison = (
    df.groupby("Season")[
        [revenue_column, cost_column, profit_column]
    ]
    .mean()
    .round(2)
)

economic_comparison
economic_comparison.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Economic Performance Comparison Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Amount")

plt.xticks(rotation=0)

plt.legend(title="Economic Metrics")

plt.tight_layout()

plt.show()

# %%
####Regional and Crop-Level Seasonal Analysis\

# %%
#first regional 
state_columns = [
    col for col in df.columns
    if "state" in col.lower()
]

print(state_columns)
# Out:
# ['State']

# %%
#avg yield by state and season
state_column = state_columns[0]

state_season_yield = (
    df.groupby([state_column, "Season"])["Yield_Tonnes_Ha"]
    .mean()
    .round(2)
    .unstack()
)

state_season_yield
plt.figure(figsize=(12, 7))

sns.heatmap(
    state_season_yield,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu"
)

plt.title("Average Agricultural Yield by State and Season")
plt.xlabel("Season")
plt.ylabel("State")

plt.show()

# %%
#Average Profit by State and Season
state_season_profit = (
    df.groupby([state_column, "Season"])[profit_column]
    .mean()
    .round(2)
    .unstack()
)

state_season_profit
plt.figure(figsize=(12, 7))

sns.heatmap(
    state_season_profit,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu"
)

plt.title("Average Profit by State and Season")
plt.xlabel("Season")
plt.ylabel("State")

plt.show()

# %%
#now secondly Crop-Level Analysis

# %%
crop_columns = [
    col for col in df.columns
    if "crop" in col.lower()
]

print(crop_columns)
# Out:
# ['Crop']

# %%
#avg yield by crop and season
crop_column = crop_columns[0]

crop_season_yield = (
    df.groupby([crop_column, "Season"])["Yield_Tonnes_Ha"]
    .mean()
    .round(2)
    .unstack()
)

crop_season_yield
plt.figure(figsize=(12, 7))

sns.heatmap(
    crop_season_yield,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu"
)

plt.title("Average Yield by Crop and Season")
plt.xlabel("Season")
plt.ylabel("Crop")

plt.show()

# %%
##Average Profit by Crop and Season
crop_season_profit = (
    df.groupby([crop_column, "Season"])[profit_column]
    .mean()
    .round(2)
    .unstack()
)

crop_season_profit
plt.figure(figsize=(12, 7))

sns.heatmap(
    crop_season_profit,
    annot=True,
    fmt=".2f",
    cmap="YlGnBu"
)

plt.title("Average Profit by Crop and Season")
plt.xlabel("Season")
plt.ylabel("Crop")

plt.show()

# %%
# best season for each crop based on average yield
best_season_by_crop = (
    df.groupby([crop_column, "Season"])["Yield_Tonnes_Ha"]
    .mean()
    .reset_index()
    .sort_values("Yield_Tonnes_Ha", ascending=False)
    .groupby(crop_column)
    .first()
)

best_season_by_crop
# Out:
#            Season  Yield_Tonnes_Ha
# Crop
# Chilli     Kharif         1.731459
# Cotton     Kharif         1.374512
# Groundnut  Kharif         1.484974
# Maize      Kharif         2.966410
# Pulses     Kharif         1.036063
# Rice       Kharif         2.698376
# Sugarcane  Kharif        53.459120
# Wheat      Kharif         2.253664

# %%
# STATICAL ANALYSIS AND MODELING

# %%
#Descriptive Statistics of Yield by Season
yield_statistics = (
    df.groupby("Season")["Yield_Tonnes_Ha"]
    .agg(["count", "mean", "median", "std", "min", "max"])
    .round(2)
)

yield_statistics
# Out:
#         count  mean  median    std  min     max
# Season
# Kharif   1779  5.63    1.94  14.39  0.3  101.44
# Rabi     1627  5.04    1.67  12.75  0.3   93.13
# Zaid      594  4.64    1.46  11.27  0.3   64.76

# %%
#Compare Yield Distribution Across Seasons
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha"
)

plt.title("Yield Distribution Across Seasons")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes per Hectare)")

plt.show()

# %%
#Voilin Plot 
plt.figure(figsize=(9, 6))

sns.violinplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha"
)

plt.title("Yield Distribution Density Across Seasons")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes per Hectare)")

plt.show()

# %%
#Yield distribution diagram (histplot)
plt.figure(figsize=(9, 6))

sns.histplot(
    data=df,
    x="Yield_Tonnes_Ha",
    hue="Season",
    kde=True,
    bins=30
)

plt.title("Distribution of Agricultural Yield")
plt.xlabel("Yield (Tonnes per Hectare)")
plt.ylabel("Frequency")

plt.show()

# %%
#Correlatiopn analysis
correlation_columns = [
    "Rainfall_mm",
    "Avg_Temperature_C",
    "Humidity_pct",
    "Sunlight_Hours_Day",
    "Soil_Moisture_pct",
    "Yield_Tonnes_Ha"
]

correlation_matrix = df[correlation_columns].corr()

correlation_matrix.round(2)
# Out:
#                     Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Rainfall_mm                1.00               0.20          0.52
# Avg_Temperature_C          0.20               1.00          0.14
# Humidity_pct               0.52               0.14          1.00
# Sunlight_Hours_Day        -0.36              -0.03         -0.30
# Soil_Moisture_pct          0.51               0.08          0.45
# Yield_Tonnes_Ha            0.03               0.01          0.01
#
#                     Sunlight_Hours_Day  Soil_Moisture_pct  Yield_Tonnes_Ha
# Rainfall_mm                      -0.36               0.51             0.03
# Avg_Temperature_C                -0.03               0.08             0.01
# Humidity_pct                     -0.30               0.45             0.01
# Sunlight_Hours_Day                1.00              -0.30            -0.02
# Soil_Moisture_pct                -0.30               1.00             0.01
# ...

# %%
#correlation heatmapplt.figure(figsize=(10, 7))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Between Environmental Factors and Yield")

plt.show()

# %%
#seasonal yield variablity
#(formula to find -Coefficient of Variation = (Standard Deviation / Mean) × 100)
yield_variability = (
    df.groupby("Season")["Yield_Tonnes_Ha"]
    .agg(["mean", "std"])
)

yield_variability["CV_Percentage"] = (
    yield_variability["std"] /
    yield_variability["mean"]
) * 100

yield_variability.round(2)
# Out:
#         mean    std  CV_Percentage
# Season
# Kharif  5.63  14.39         255.71
# Rabi    5.04  12.75         253.04
# Zaid    4.64  11.27         242.89

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    x=yield_variability.index,
    y=yield_variability["CV_Percentage"]
)

plt.title("Yield Variability Across Seasons")
plt.xlabel("Season")
plt.ylabel("Coefficient of Variation (%)")
 

plt.show()

# %%
#$Seasonal Mean Yield with Confidence Intervals
plt.figure(figsize=(9, 6))

sns.barplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha",
    errorbar=("ci", 95)
)

plt.title("Average Yield by Season with 95% Confidence Intervals")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes per Hectare)")

plt.show()

# %%
# now summary table 
statistical_summary = (
    df.groupby("Season")["Yield_Tonnes_Ha"]
    .agg(
        Mean="mean",
        Median="median",
        Standard_Deviation="std",
        Variance="var",
        Minimum="min",
        Maximum="max"
    )
    .round(2)
)

statistical_summary
# Out:
#         Mean  Median  Standard_Deviation  Variance  Minimum  Maximum
# Season
# Kharif  5.63    1.94               14.39    207.15      0.3   101.44
# Rabi    5.04    1.67               12.75    162.60      0.3    93.13
# Zaid    4.64    1.46               11.27    127.08      0.3    64.76

# %%
#Unusal seasonal patterns

# %%
#Yoield outliers by season 
# Identify yield outliers for each season using the IQR method

outlier_results = []

for season in df["Season"].unique():
    
    season_yield = df.loc[
        df["Season"] == season,
        "Yield_Tonnes_Ha"
    ]
    
    Q1 = season_yield.quantile(0.25)
    Q3 = season_yield.quantile(0.75)
    IQR = Q3 - Q1
    
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    
    outliers = season_yield[
        (season_yield < lower_limit) |
        (season_yield > upper_limit)
    ]
    
    outlier_results.append({
        "Season": season,
        "Lower_Limit": lower_limit,
        "Upper_Limit": upper_limit,
        "Outlier_Count": len(outliers)
    })

outlier_results = pd.DataFrame(outlier_results)

outlier_results
# Out:
#    Season  Lower_Limit  Upper_Limit  Outlier_Count
# 0  Kharif      -1.7000       5.9800            121
# 1    Rabi      -1.5475       5.3125            125
# 2    Zaid      -1.2700       4.4100             50

# %%
#now vizualize the outliers
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha"
)

plt.title("Yield Distribution and Outliers by Season")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes per Hectare)")
plt.tight_layout()
plt.show()

# %%
#highest and lowest yielsd observations
highest_yield = df.loc[
    df["Yield_Tonnes_Ha"].idxmax()
]

lowest_yield = df.loc[
    df["Yield_Tonnes_Ha"].idxmin()
]

print("Highest Yield Observation:")
print(highest_yield)

print("\nLowest Yield Observation:")
print(lowest_yield)
# Out:
# Highest Yield Observation:
# Farm_ID                            SF11716
# State                              Gujarat
# District                            Indore
# Crop                             Sugarcane
# Season                              Kharif
# Farm_Area_Hectares                    6.32
# Rainfall_mm                          689.0
# Avg_Temperature_C                     29.6
# Humidity_pct                          68.2
# Sunlight_Hours_Day                     5.9
# Soil_pH                               6.68
# Soil_Moisture_pct                     30.5
# Nitrogen_kg_ha                       125.9
# Phosphorus_kg_ha                      71.8
# Potassium_kg_ha                      103.9
# Irrigation_Method                     Drip
# Fertilizer_kg_ha                     171.0
# Pesticide_Litre_ha                     0.5
# Seed_Quality_Score                    0.75
# Yield_Tonnes_Ha                     101.44
# Production_Tonnes                    641.1
# ...

# %%
#Check Whether High Yield Is Concentrated in One Season
# Compare the maximum yield observed in each season

maximum_yield_by_season = (
    df.groupby("Season")["Yield_Tonnes_Ha"]
    .max()
    .sort_values(ascending=False)
)

maximum_yield_by_season
# Out:
# Season
# Kharif    101.44
# Rabi       93.13
# Zaid       64.76
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=maximum_yield_by_season.index,
    y=maximum_yield_by_season.values
)

plt.title("Maximum Yield Observed by Season")
plt.xlabel("Season")
plt.ylabel("Maximum Yield (Tonnes per Hectare)")
plt.tight_layout()
plt.show()

# %%
#once Check for Unexpected Profitability
season_profit = (
    df.groupby("Season")["Profit_INR"]
    .mean()
    .sort_values()
)

plt.figure(figsize=(10, 6))

sns.barplot(
    x=season_profit.index,
    y=season_profit.values
)

plt.axhline(
    0,
    linestyle="--"
)

plt.title("Average Profit by Season")
plt.xlabel("Season")
plt.ylabel("Average Profit (INR)")
plt.tight_layout()
plt.show()

# %%
zaid_economics = df.groupby("Season").agg(
    Average_Revenue=("Revenue_INR", "mean"),
    Average_Cost=("Total_Cost_INR", "mean"),
    Average_Profit=("Profit_INR", "mean")
).round(2)

zaid_economics
# here we can see that Zaid has a negative average profit, indicating that agricultural activities during this season resulted in an average loss. This is an important observation for farmers and policymakers to consider when planning agricultural activities for the Zaid season.
# Out:
#         Average_Revenue  Average_Cost  Average_Profit
# Season
# Kharif        710719.06     531804.41       178914.65
# Rabi          601526.05     513836.58        87689.47
# Zaid          519171.90     543976.73       -24804.82

# %%
zaid_economics[
    ["Average_Revenue", "Average_Cost"]
].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Average Revenue and Cost by Season")
plt.xlabel("Season")
plt.ylabel("Amount (INR)")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# here we check crop level expectations
crop_season_yield = (
    df.groupby(["Crop", "Season"])["Yield_Tonnes_Ha"]
    .mean()
    .reset_index()
)

crop_season_pivot = crop_season_yield.pivot(
    index="Crop",
    columns="Season",
    values="Yield_Tonnes_Ha"
)

crop_season_pivot.round(2)
# Out:
# Season     Kharif   Rabi   Zaid
# Crop
# Chilli       1.73   1.47   1.20
# Cotton       1.37   1.20   0.96
# Groundnut    1.48   1.23   1.04
# Maize        2.97   2.60   2.29
# Pulses       1.04   0.88   0.67
# Rice         2.70   2.32   1.90
# Sugarcane   53.46  43.29  38.42
# Wheat        2.25   2.06   1.75

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(
    crop_season_pivot,
    annot=True,
    fmt=".2f"
)

plt.title("Average Crop Yield Across Seasons")
plt.xlabel("Season")
plt.ylabel("Crop")
plt.tight_layout()
plt.show()

# %%
#regional level expectations
state_season_yield = (
    df.groupby(["State", "Season"])["Yield_Tonnes_Ha"]
    .mean()
    .reset_index()
)

state_season_pivot = state_season_yield.pivot(
    index="State",
    columns="Season",
    values="Yield_Tonnes_Ha"
)

state_season_pivot.round(2)
# Out:
# Season          Kharif  Rabi  Zaid
# State
# Andhra Pradesh    5.68  3.47  4.45
# Gujarat           6.34  5.44  4.07
# Karnataka         6.46  4.57  6.62
# Madhya Pradesh    5.99  3.76  5.48
# Maharashtra       5.43  5.50  2.28
# Punjab            4.10  8.61  5.91
# Tamil Nadu        5.52  4.50  4.10
# Telangana         5.55  4.78  4.25

# %%
#heatmap
plt.figure(figsize=(12, 8))

sns.heatmap(
    state_season_pivot,
    annot=True,
    fmt=".2f"
)

plt.title("Average Yield by State and Season")
plt.xlabel("Season")
plt.ylabel("State")
plt.tight_layout()
plt.show()

# %%
#
# Out:
# Season with highest average yield: Kharif
# Season with lowest average yield: Zaid
#
# Season with highest average profit: Kharif
# Season with lowest average profit: Zaid

# %%
#FImal insights and key findings

# %%
#overall peerformance
# Create a consolidated seasonal performance table

final_summary = df.groupby("Season").agg(
    Average_Yield=("Yield_Tonnes_Ha", "mean"),
    Total_Production=("Production_Tonnes", "sum"),
    Average_Revenue=("Revenue_INR", "mean"),
    Average_Cost=("Total_Cost_INR", "mean"),
    Average_Profit=("Profit_INR", "mean"),
    Average_Water_Used=("Water_Used_m3", "mean"),
    Average_Water_Efficiency=("Water_Efficiency_t_per_1000m3", "mean")
).round(2)

final_summary
# Out:
#         Average_Yield  Total_Production  Average_Revenue  Average_Cost  \
# Season
# Kharif           5.63          82387.61        710719.06     531804.41
# Rabi             5.04          67498.88        601526.05     513836.58
# Zaid             4.64          23098.35        519171.90     543976.73
#
#         Average_Profit  Average_Water_Used  Average_Water_Efficiency
# Season
# Kharif       178914.65             6102.20                      5.89
# Rabi          87689.47             5846.99                      5.19
# Zaid         -24804.82             6419.89                      4.41

# %%
#avg yielsd
plt.figure(figsize=(10, 6))

sns.barplot(
    data=final_summary.reset_index(),
    x="Season",
    y="Average_Yield"
)

plt.title("Average Yield by Season")
plt.xlabel("Season")
plt.ylabel("Average Yield (Tonnes per Hectare)")
plt.tight_layout()
plt.show()

# %%
#avg profit
plt.figure(figsize=(10, 6))

sns.barplot(
    data=final_summary.reset_index(),
    x="Season",
    y="Average_Profit"
)

plt.axhline(0, linestyle="--")

plt.title("Average Profit by Season")
plt.xlabel("Season")
plt.ylabel("Average Profit (INR)")
plt.tight_layout()
plt.show()

# %%
#rank the season based on average yield

yield_ranking = (
    final_summary["Average_Yield"]
    .sort_values(ascending=False)
)

yield_ranking
# Out:
# Season
# Kharif    5.63
# Rabi      5.04
# Zaid      4.64
# Name: Average_Yield, dtype: float64

# %%
# Rank seasons based on average profit

profit_ranking = (
    final_summary["Average_Profit"]
    .sort_values(ascending=False)
)

profit_ranking
# Out:
# Season
# Kharif    178914.65
# Rabi       87689.47
# Zaid      -24804.82
# Name: Average_Profit, dtype: float64

# %%
#calculate profit margin 

final_summary["Profit_Margin_%"] = (
    final_summary["Average_Profit"] /
    final_summary["Average_Revenue"]
) * 100

final_summary["Profit_Margin_%"] = (
    final_summary["Profit_Margin_%"].round(2)
)

final_summary

#plot
plt.figure(figsize=(10, 6))

sns.barplot(
    data=final_summary.reset_index(),
    x="Season",
    y="Profit_Margin_%"
)

plt.axhline(0, linestyle="--")

plt.title("Profit Margin by Season")
plt.xlabel("Season")
plt.ylabel("Profit Margin (%)")
plt.tight_layout()
plt.show()

# %%
# Identify best and weakest seasons

best_yield_season = final_summary["Average_Yield"].idxmax()
worst_yield_season = final_summary["Average_Yield"].idxmin()

best_profit_season = final_summary["Average_Profit"].idxmax()
worst_profit_season = final_summary["Average_Profit"].idxmin()

print("Highest average yield:", best_yield_season)
print("Lowest average yield:", worst_yield_season)

print("Highest average profit:", best_profit_season)
print("Lowest average profit:", worst_profit_season)
# Out:
# Highest average yield: Kharif
# Lowest average yield: Zaid
# Highest average profit: Kharif
# Lowest average profit: Zaid

# %%
# Create a concise summary of the major findings

key_findings = pd.DataFrame({
    "Indicator": [
        "Average Yield",
        "Total Production",
        "Average Revenue",
        "Average Profit",
        "Profit Margin"
    ],
    "Best Season": [
        final_summary["Average_Yield"].idxmax(),
        final_summary["Total_Production"].idxmax(),
        final_summary["Average_Revenue"].idxmax(),
        final_summary["Average_Profit"].idxmax(),
        final_summary["Profit_Margin_%"].idxmax()
    ],
    "Lowest Season": [
        final_summary["Average_Yield"].idxmin(),
        final_summary["Total_Production"].idxmin(),
        final_summary["Average_Revenue"].idxmin(),
        final_summary["Average_Profit"].idxmin(),
        final_summary["Profit_Margin_%"].idxmin()
    ]
})

key_findings
#FINAL Findings table
# Out:
#           Indicator Best Season Lowest Season
# 0     Average Yield      Kharif          Zaid
# 1  Total Production      Kharif          Zaid
# 2   Average Revenue      Kharif          Zaid
# 3    Average Profit      Kharif          Zaid
# 4     Profit Margin      Kharif          Zaid

# %%
# Key Insights
# ============================================================

# After completing all previous analyses, the following key
# insights were identified from the agricultural dataset.

# 1. Seasonal Performance
# Kharif showed the strongest overall performance based on
# average yield, total production, revenue, and profit.

# 2. Production
# Kharif recorded the highest total production, while Zaid
# recorded the lowest total production.

# 3. Economic Performance
# Kharif generated the highest average revenue and average profit
# among the three seasons.

# 4. Important Unusual Finding
# Zaid recorded a negative average profit despite generating
# agricultural revenue. This shows that generating revenue alone
# does not necessarily result in profitability.

# 5. Seasonal Differences
# Yield, production, revenue, and profitability vary considerably
# across Kharif, Rabi, and Zaid seasons.

# 6. Environmental Relationships
# Correlation and scatterplot analysis should be used to identify
# which environmental factors have the strongest association
# with agricultural yield.
# Note: correlation indicates association, not causation.

# 7. Resource Usage
# Water, fertilizer, pesticide, and irrigation usage should be
# interpreted together with yield to understand whether higher
# resource consumption is associated with better performance.

# 8. Regional and Crop Differences
# State-season and crop-season analysis should be used to identify
# cases where the overall seasonal pattern does not hold.
# This helps determine whether seasonal performance remains
# consistent across different regions and crop categories.

# %%
#conclusion

# %%
#Final Seasonal Performance Chart
# Final comparison of average yield, revenue and profit

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

sns.barplot(
    data=final_summary.reset_index(),
    x="Season",
    y="Average_Yield",
    ax=axes[0]
)

axes[0].set_title("Average Yield by Season")
axes[0].set_xlabel("Season")
axes[0].set_ylabel("Yield (Tonnes/Ha)")


sns.barplot(
    data=final_summary.reset_index(),
    x="Season",
    y="Average_Revenue",
    ax=axes[1]
)

axes[1].set_title("Average Revenue by Season")
axes[1].set_xlabel("Season")
axes[1].set_ylabel("Revenue (INR)")


sns.barplot(
    data=final_summary.reset_index(),
    x="Season",
    y="Average_Profit",
    ax=axes[2]
)

axes[2].axhline(0, linestyle="--")
axes[2].set_title("Average Profit by Season")
axes[2].set_xlabel("Season")
axes[2].set_ylabel("Profit (INR)")

plt.tight_layout()
plt.show()

# %%
# Calculate the percentage difference between the best and lowest seasons

yield_difference = (
    (
        final_summary["Average_Yield"].max()
        - final_summary["Average_Yield"].min()
    )
    / final_summary["Average_Yield"].min()
) * 100

profit_difference = (
    final_summary["Average_Profit"].max()
    - final_summary["Average_Profit"].min()
)

print("Best season for average yield:",
      final_summary["Average_Yield"].idxmax())

print("Lowest season for average yield:",
      final_summary["Average_Yield"].idxmin())

print("Percentage difference between highest and lowest average yield:",
      round(yield_difference, 2), "%")

print("Best season for average profit:",
      final_summary["Average_Profit"].idxmax())

print("Lowest season for average profit:",
      final_summary["Average_Profit"].idxmin())

print("Difference between highest and lowest average profit:",
      round(profit_difference, 2))
# Out:
# Best season for average yield: Kharif
# Lowest season for average yield: Zaid
# Percentage difference between highest and lowest average yield: 21.34 %
# Best season for average profit: Kharif
# Lowest season for average profit: Zaid
# Difference between highest and lowest average profit: 203719.47

# %%
'''## Conclusion

The Seasonal Agriculture Performance Analysis shows that agricultural performance varies across seasons in terms of yield, production, revenue and profitability.

Among the three seasons analyzed, Kharif demonstrated the strongest overall performance. It recorded the highest average yield, total production, average revenue and average profit in the dataset. Rabi showed moderate performance across the major agricultural and economic indicators, while Zaid recorded comparatively lower performance.

An important finding was the negative average profit observed for Zaid. This indicates that higher agricultural activity or revenue does not necessarily result in higher profitability. The relationship between revenue, production costs and profit therefore needs to be considered when evaluating seasonal agricultural performance.

The analysis of environmental conditions and resource usage also provided insights into the factors associated with seasonal differences. Relationships between rainfall, temperature, soil moisture, water usage, fertilizer usage and yield were examined using statistical and visualization techniques.

Regional and crop-level comparisons further showed that overall seasonal performance should not be interpreted as being identical for every crop or geographical area. Some categories may perform differently from the overall seasonal trend.

Statistical analysis, including descriptive statistics, correlation analysis and ANOVA, was used to evaluate variations and relationships within the data. These results provide statistical evidence for interpreting the observed seasonal differences.

Overall, the analysis demonstrates that seasonal conditions can have an important influence on agricultural productivity and economic performance. The findings can support more informed seasonal planning by considering crop type, geographical conditions, resource requirements, environmental factors and expected profitability.
# Out:
#   Cell In[163], line 1
#     '''## Conclusion
#     ^
# _IncompleteInputError: incomplete input

# %%
# Compare average revenue, cost and profit across seasons

economic_summary = df.groupby("Season").agg(
    Average_Revenue=("Revenue_INR", "mean"),
    Average_Cost=("Total_Cost_INR", "mean"),
    Average_Profit=("Profit_INR", "mean")
).round(2)

economic_summary.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Economic Performance by Season")
plt.xlabel("Season")
plt.ylabel("Amount (INR)")
plt.xticks(rotation=0)
plt.legend()
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

sns.barplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha",
    ax=axes[0, 0]
)
axes[0, 0].set_title("Average Yield by Season")
axes[0, 0].set_xlabel("Season")
axes[0, 0].set_ylabel("Yield (Tonnes/Ha)")


sns.barplot(
    data=df,
    x="Season",
    y="Production_Tonnes",
    ax=axes[0, 1]
)
axes[0, 1].set_title("Average Production by Season")
axes[0, 1].set_xlabel("Season")
axes[0, 1].set_ylabel("Production (Tonnes)")


sns.barplot(
    data=df,
    x="Season",
    y="Revenue_INR",
    ax=axes[1, 0]
)
axes[1, 0].set_title("Average Revenue by Season")
axes[1, 0].set_xlabel("Season")
axes[1, 0].set_ylabel("Revenue (INR)")


sns.barplot(
    data=df,
    x="Season",
    y="Profit_INR",
    ax=axes[1, 1]
)
axes[1, 1].axhline(0, linestyle="--")
axes[1, 1].set_title("Average Profit by Season")
axes[1, 1].set_xlabel("Season")
axes[1, 1].set_ylabel("Profit (INR)")


plt.suptitle(
    "Seasonal Agricultural Performance",
    fontsize=16
)

plt.tight_layout()
plt.show()

# %%
# Seasonal Agriculture Performance Visualization Dashboard

fig, axes = plt.subplots(2, 4, figsize=(22, 10))

# 1. Season Distribution
sns.countplot(
    data=df,
    x="Season",
    ax=axes[0, 0]
)

axes[0, 0].set_title("Number of Farms by Season")
axes[0, 0].set_xlabel("Season")
axes[0, 0].set_ylabel("Number of Farms")


# 2. Average Yield
sns.barplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha",
    ax=axes[0, 1]
)

axes[0, 1].set_title("Average Yield by Season")
axes[0, 1].set_xlabel("Season")
axes[0, 1].set_ylabel("Yield (Tonnes/Ha)")


# 3. Yield Distribution
sns.boxplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha",
    ax=axes[0, 2]
)

axes[0, 2].set_title("Yield Distribution by Season")
axes[0, 2].set_xlabel("Season")
axes[0, 2].set_ylabel("Yield (Tonnes/Ha)")


# 4. Violin Plot
sns.violinplot(
    data=df,
    x="Season",
    y="Yield_Tonnes_Ha",
    ax=axes[0, 3]
)

axes[0, 3].set_title("Yield Distribution Shape")
axes[0, 3].set_xlabel("Season")
axes[0, 3].set_ylabel("Yield (Tonnes/Ha)")


# 5. Rainfall vs Yield
sns.scatterplot(
    data=df,
    x="Rainfall_mm",
    y="Yield_Tonnes_Ha",
    hue="Season",
    ax=axes[1, 0],
    legend=False
)

axes[1, 0].set_title("Rainfall vs Yield")
axes[1, 0].set_xlabel("Rainfall (mm)")
axes[1, 0].set_ylabel("Yield (Tonnes/Ha)")


# 6. Average Profit
sns.barplot(
    data=df,
    x="Season",
    y="Profit_INR",
    ax=axes[1, 1]
)

axes[1, 1].axhline(0, linestyle="--")

axes[1, 1].set_title("Average Profit by Season")
axes[1, 1].set_xlabel("Season")
axes[1, 1].set_ylabel("Profit (INR)")


# 7. Average Water Usage
sns.barplot(
    data=df,
    x="Season",
    y="Water_Used_m3",
    ax=axes[1, 2]
)

axes[1, 2].set_title("Average Water Usage")
axes[1, 2].set_xlabel("Season")
axes[1, 2].set_ylabel("Water Used (m³)")


# Remove unused 8th subplot
axes[1, 3].axis("off")


plt.suptitle(
    "Seasonal Agriculture Performance Dashboard",
    fontsize=18
)

plt.tight_layout()
plt.show()
